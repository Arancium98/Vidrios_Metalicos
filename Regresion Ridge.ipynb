# %%
#Liberias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge

# %%
#%%Lectura y feature engineering
Datos = pd.read_csv('dataset/Tabla_pasantia_cleaned.csv', sep=',', skiprows=1, names=['test', 'Cu_per', 'Zr_per', 'Crate', 'Lx', 'Ly', 'Lz', 'Srate', 'T', 'E', 'Smax'])
Datos = Datos.drop(['Cu_per','Zr_per','Lx','Ly','Lz'],axis=1)

# %%
#One hot encoding
Datos['test'] = OneHotEncoder().fit_transform(Datos['test'].to_numpy().reshape(-1,1)).toarray()
#Escalamiento
Data_scaled = MinMaxScaler().fit_transform(Datos)
#Transformacion a Pandas
Data_scaled_pandas = pd.DataFrame(Data_scaled, columns = ['test', 'Crate', 'Srate', 'T', 'E', 'Smax'])

# %% [markdown]
# # variables independientes: Test, Crate, Srate, T, E

# %%
#Random 32
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=32)

# %%
#%%Preparacion modelo Ridge regression
#Enttrenamiento de algoritmo
ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)

# %%
#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1234
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1234)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 2836
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2836)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1547
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1547)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7854
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7854)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 3466
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=3466)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 5374
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=5374)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7845
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7845)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 4987
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4987)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 4236
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T', 'E']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4236)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %% [markdown]
# ## Test sin E

# %%
#Random 4236
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4236)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1245
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1245)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 4878
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4878)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1478
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1478)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 8741
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=8741)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1236
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1236)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 5487
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=5487)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 5487
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=5487)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 9654
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=9654)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 2541
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate', 'Srate', 'T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2541)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %% [markdown]
# ## Test sin E ni Strate

# %%
#Random 2541
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate','T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2541)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1478
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate','T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1478)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1589
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate','T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1589)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 2365
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate','T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2365)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 8965
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate','T']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1587)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %% [markdown]
# ## Test sin E ni Strate ni T

# %%
#Random 1587
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1587)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 2
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 5245
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=5245)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 9856
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=9856)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 4596
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4596)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 1478
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1478)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 6325
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=6325)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 8523
#%%Division en training y testing
X = Data_scaled_pandas[['test', 'Crate']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=8523)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %% [markdown]
# ## Test sin E ni Strate ni T ,crate

# %%
#Random 8523
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=8523)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 123
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=123)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 2345
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=2345)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 3456
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=3456)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7567
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7567)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 6854
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=6854)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7658
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7658)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 4565
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=4565)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7895
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7895)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 7896
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=7896)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 8965
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=8965)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))

# %%
#Random 8526
#%%Division en training y testing
X = Data_scaled_pandas[['test']]
y = Data_scaled_pandas['Smax']
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=8526)

ridge = Ridge().fit(X_train,y_train)

#Coeficientes e intercepto
print("\nRegresion Ridge")
print("coeficientes:", ridge.coef_)
print("Intercepto:", ridge.intercept_)


#Calculo de R^2 para training y testing
#En training
print("R^2 de train:", ridge.score(X_train,y_train))
#En testing (Prueba del algoritmo)
print("R^2 de test:", ridge.score(X_test,y_test))
